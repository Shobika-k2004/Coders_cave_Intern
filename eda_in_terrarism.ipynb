# %% [markdown]
# importing libarries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# reading the file

# %%
df=pd.read_csv("/content/globalterrorismdb_0718dist.csv",encoding='latin-1')
# Out:
# <ipython-input-2-9c9fd3d28e54>:1: DtypeWarning: Columns (4,31,33,76,94,96,121) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv("/content/globalterrorismdb_0718dist.csv",encoding='latin-1')

# %% [markdown]
# import warning and ignore to ignore wrning

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
df.head()
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
# 1              Mexico       1  ...      NaN    NaN    NaN     NaN      PGIS
# 2         Philippines       5  ...      NaN    NaN    NaN     NaN      PGIS
# 3              Greece       8  ...      NaN    NaN    NaN     NaN      PGIS
# 4               Japan       4  ...      NaN    NaN    NaN     NaN      PGIS
#
#    INT_LOG  INT_IDEO INT_MISC INT_ANY  related
# 0      0.0       0.0      0.0     0.0      NaN
# 1      0.0       1.0      1.0     1.0      NaN
# 2     -9.0      -9.0      1.0     1.0      NaN
# 3     -9.0      -9.0      1.0     1.0      NaN
# 4     -9.0      -9.0      1.0     1.0      NaN
#
# [5 rows x 135 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11960 entries, 0 to 11959
# Columns: 135 entries, eventid to related
# dtypes: float64(63), int64(18), object(54)
# memory usage: 12.3+ MB

# %%
df.describe()
# Out:
#             eventid         iyear        imonth          iday      extended  \
# count  1.196000e+04  11960.000000  11960.000000  11960.000000  11960.000000
# mean   1.976790e+11   1976.726338      6.170569     15.243227      0.023411
# std    3.022204e+08      3.024931      3.338024      8.942614      0.151212
# min    1.970000e+11   1970.000000      0.000000      0.000000      0.000000
# 25%    1.975050e+11   1975.000000      3.000000      8.000000      0.000000
# 50%    1.978022e+11   1978.000000      6.000000     15.000000      0.000000
# 75%    1.979073e+11   1979.000000      9.000000     23.000000      0.000000
# max    1.980093e+11   1980.000000     12.000000     31.000000      1.000000
#
#             country        region      latitude     longitude   specificity  \
# count  11960.000000  11960.000000  11570.000000  11570.000000  11960.000000
# mean     205.097910      5.881355     31.330726    -22.842727      1.213796
# std      181.789798      3.326011     22.026742     54.525074      0.841495
# min        4.000000      1.000000    -45.867889   -157.818968      1.000000
# 25%       83.000000      2.000000     14.622869    -75.416953      1.000000
# 50%      155.000000      8.000000     39.930771     -5.956210      1.000000
# 75%      217.000000      8.000000     45.434336     11.346518      1.000000
# max      605.000000     12.000000     64.837778    172.636225      5.000000
#
#        ...     ransomamt  ransomamtus    ransompaid  ransompaidus  \
# count  ...  3.500000e+02          1.0  8.100000e+01           1.0
# mean   ...  4.202714e+06      20000.0  1.461872e+06           0.0
# std    ...  5.377014e+07          NaN  5.045784e+06           NaN
# min    ...  0.000000e+00      20000.0  0.000000e+00           0.0
# 25%    ...  0.000000e+00      20000.0  0.000000e+00           0.0
# 50%    ...  0.000000e+00      20000.0  8.000000e+04           0.0
# 75%    ...  4.132500e+05      20000.0  1.000000e+06           0.0
# max    ...  1.000000e+09      20000.0  4.100000e+07           0.0
#
#        hostkidoutcome   nreleased       INT_LOG      INT_IDEO      INT_MISC  \
# count      518.000000  400.000000  11959.000000  11959.000000  11959.000000
# mean         2.839768    5.982500     -3.326532     -3.278284      0.310059
# std          1.265294   23.322243      4.476546      4.525668      0.663122
# min          2.000000  -99.000000     -9.000000     -9.000000     -9.000000
# 25%          2.000000    1.000000     -9.000000     -9.000000      0.000000
# 50%          2.000000    1.000000      0.000000      0.000000      0.000000
# 75%          4.000000    2.000000      0.000000      0.000000      1.000000
# max          7.000000  187.000000      1.000000      1.000000      1.000000
#
#             INT_ANY
# count  11959.000000
# mean      -2.122335
# std        4.364938
# min       -9.000000
# 25%       -9.000000
# 50%        0.000000
# 75%        1.000000
# max        1.000000
#
# [8 rows x 81 columns]

# %%
df.shape
# Out:
# (11960, 135)

# %%
df.columns
# Out:
# Index(['eventid', 'iyear', 'imonth', 'iday', 'approxdate', 'extended',
#        'resolution', 'country', 'country_txt', 'region',
#        ...
#        'addnotes', 'scite1', 'scite2', 'scite3', 'dbsource', 'INT_LOG',
#        'INT_IDEO', 'INT_MISC', 'INT_ANY', 'related'],
#       dtype='object', length=135)

# %%
for i in df.columns:
  print(i)
# Out:
# eventid
# iyear
# imonth
# iday
# approxdate
# extended
# resolution
# country
# country_txt
# region
# region_txt
# provstate
# city
# latitude
# longitude
# specificity
# vicinity
# location
# summary
# crit1
# crit2
# crit3
# doubtterr
# alternative
# alternative_txt
# multiple
# success
# suicide
# attacktype1
# attacktype1_txt
# attacktype2
# attacktype2_txt
# attacktype3
# attacktype3_txt
# targtype1
# targtype1_txt
# targsubtype1
# targsubtype1_txt
# corp1
# target1
# natlty1
# natlty1_txt
# targtype2
# targtype2_txt
# targsubtype2
# targsubtype2_txt
# corp2
# target2
# natlty2
# natlty2_txt
# targtype3
# targtype3_txt
# targsubtype3
# targsubtype3_txt
# corp3
# target3
# natlty3
# natlty3_txt
# gname
# gsubname
# gname2
# gsubname2
# gname3
# gsubname3
# motive
# guncertain1
# guncertain2
# guncertain3
# individual
# nperps
# nperpcap
# claimed
# claimmode
# claimmode_txt
# claim2
# claimmode2
# claimmode2_txt
# claim3
# claimmode3
# claimmode3_txt
# compclaim
# weaptype1
# weaptype1_txt
# weapsubtype1
# weapsubtype1_txt
# weaptype2
# weaptype2_txt
# weapsubtype2
# weapsubtype2_txt
# weaptype3
# weaptype3_txt
# weapsubtype3
# weapsubtype3_txt
# weaptype4
# weaptype4_txt
# weapsubtype4
# weapsubtype4_txt
# weapdetail
# nkill
# nkillus
# nkillter
# nwound
# nwoundus
# nwoundte
# property
# propextent
# propextent_txt
# propvalue
# propcomment
# ishostkid
# nhostkid
# nhostkidus
# nhours
# ndays
# divert
# kidhijcountry
# ransom
# ransomamt
# ransomamtus
# ransompaid
# ransompaidus
# ransomnote
# hostkidoutcome
# hostkidoutcome_txt
# nreleased
# addnotes
# scite1
# scite2
# scite3
# dbsource
# INT_LOG
# INT_IDEO
# INT_MISC
# INT_ANY
# related

# %% [markdown]
# Data preprocessing

# %%
df.dtypes
# Out:
# eventid         int64
# iyear           int64
# imonth          int64
# iday            int64
# approxdate     object
#                ...
# INT_LOG       float64
# INT_IDEO      float64
# INT_MISC      float64
# INT_ANY       float64
# related        object
# Length: 135, dtype: object

# %% [markdown]
# Taking only specified columns

# %%
df = df[['iyear','imonth','iday','country_txt','provstate','region_txt',
                       'attacktype1_txt','target1','nkill','nwound','summary','gname',
                       'targtype1_txt','weaptype1_txt','motive']]

# %%
df.columns
# Out:
# Index(['iyear', 'imonth', 'iday', 'country_txt', 'provstate', 'region_txt',
#        'attacktype1_txt', 'target1', 'nkill', 'nwound', 'summary', 'gname',
#        'targtype1_txt', 'weaptype1_txt', 'motive'],
#       dtype='object')

# %%
df.rename(columns={'iyear':'Year','imonth':'Month','iday':'Day','country_txt':'Country','provstate':'State',
                       'region_txt':'Region','attacktype1_txt':'AttackType','target1':'Target','nkill':'Killed',
                       'nwound':'Wounded','summary':'Summary','gname':'Group','targtype1_txt':'Target_type',
                       'weaptype1_txt':'Weapon_type','motive':'Motive'},inplace=True)

# %%
df.head(2)
# Out:
#    Year  Month  Day             Country    State                       Region  \
# 0  1970      7    2  Dominican Republic      NaN  Central America & Caribbean
# 1  1970      0    0              Mexico  Federal                North America
#
#                     AttackType                   Target  Killed  Wounded  \
# 0                Assassination             Julio Guzman     1.0      0.0
# 1  Hostage Taking (Kidnapping)  Nadine Chaval, daughter     0.0      0.0
#
#   Summary                               Group                  Target_type  \
# 0     NaN                              MANO-D  Private Citizens & Property
# 1     NaN  23rd of September Communist League      Government (Diplomatic)
#
#   Weapon_type Motive
# 0     Unknown    NaN
# 1     Unknown    NaN

# %%
df.duplicated().sum
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.sum of 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 11955    False
# 11956    False
# 11957    False
# 11958    False
# 11959    False
# Length: 11960, dtype: bool>

# %%
df.drop_duplicates(inplace=True)
df.shape
# Out:
# (11186, 15)

# %%
df.duplicated().any()
# Out:
# False

# %% [markdown]
# finding missing vales

# %%
df.isnull()
# Out:
#         Year  Month    Day  Country  State  Region  AttackType  Target  \
# 0      False  False  False    False   True   False       False   False
# 1      False  False  False    False  False   False       False   False
# 2      False  False  False    False  False   False       False   False
# 3      False  False  False    False  False   False       False   False
# 4      False  False  False    False  False   False       False   False
# ...      ...    ...    ...      ...    ...     ...         ...     ...
# 11955  False  False  False    False  False   False       False   False
# 11956  False  False  False    False  False   False       False   False
# 11957  False  False  False    False  False   False       False   False
# 11958  False  False  False    False  False   False       False   False
# 11959  False  False  False    False  False   False       False   False
#
#        Killed  Wounded  Summary  Group  Target_type  Weapon_type  Motive
# 0       False    False     True  False        False        False    True
# 1       False    False     True  False        False        False    True
# 2       False    False     True  False        False        False    True
# 3        True     True     True  False        False        False    True
# 4        True     True     True  False        False        False    True
# ...       ...      ...      ...    ...          ...          ...     ...
# 11955    True     True     True  False        False        False    True
# 11956   False    False     True  False        False        False    True
# 11957    True     True     True  False        False        False    True
# 11958   False    False     True  False        False        False    True
# 11959    True     True     True   True        False         True    True
#
# [11186 rows x 15 columns]

# %%
df.isnull().sum()
# Out:
# Year               0
# Month              0
# Day                0
# Country            0
# State             42
# Region             0
# AttackType         0
# Target           105
# Killed          1361
# Wounded         2689
# Summary        10332
# Group              1
# Target_type        0
# Weapon_type        1
# Motive         10567
# dtype: int64

# %%
df.isnull()
# Out:
#         Year  Month    Day  Country  State  Region  AttackType  Target  \
# 0      False  False  False    False   True   False       False   False
# 1      False  False  False    False  False   False       False   False
# 2      False  False  False    False  False   False       False   False
# 3      False  False  False    False  False   False       False   False
# 4      False  False  False    False  False   False       False   False
# ...      ...    ...    ...      ...    ...     ...         ...     ...
# 11955  False  False  False    False  False   False       False   False
# 11956  False  False  False    False  False   False       False   False
# 11957  False  False  False    False  False   False       False   False
# 11958  False  False  False    False  False   False       False   False
# 11959  False  False  False    False  False   False       False   False
#
#        Killed  Wounded  Summary  Group  Target_type  Weapon_type  Motive
# 0       False    False     True  False        False        False    True
# 1       False    False     True  False        False        False    True
# 2       False    False     True  False        False        False    True
# 3        True     True     True  False        False        False    True
# 4        True     True     True  False        False        False    True
# ...       ...      ...      ...    ...          ...          ...     ...
# 11955    True     True     True  False        False        False    True
# 11956   False    False     True  False        False        False    True
# 11957    True     True     True  False        False        False    True
# 11958   False    False     True  False        False        False    True
# 11959    True     True     True   True        False         True    True
#
# [11186 rows x 15 columns]

# %%
df['State'].count()
# Out:
# 11144

# %%
df['State']=df['State'].replace({'Unknown':np.nan})
df['State']=df['State'].fillna('Others')

df['State'].value_counts()
# Out:
# Northern Ireland    1509
# San Salvador         485
# California           395
# Lazio                384
# Others               374
#                     ...
# Aragua                 1
# Daraa                  1
# Monagas                1
# Kentucky               1
# Pointe-a-Pitre         1
# Name: State, Length: 658, dtype: int64

# %%
#checking value from target value
df['Target'].count()
# Out:
# 11081

# %%
df['Target']=df['Target'].replace({'Unknown':np.nan})
df['Target']=df['Target'].fillna('Others')

df['Target'].value_counts()
# Out:
# Others                                                             109
# Bank                                                                78
# bank                                                                43
# Police Station                                                      38
# bus                                                                 35
#                                                                   ...
# Oktar Cirit, First Secretary, Embassy                                1
# Mary Sloan, 50; Mary Sloan, 19 and Doris McGrath, 23, Catholics      1
# Kurt Walter                                                          1
# 4th Head of State: General Murtala Ramat Mohammed                    1
# policeman and troops on patrol outside cemetary                      1
# Name: Target, Length: 8948, dtype: int64

# %%
df['Target'].isnull()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 11955    False
# 11956    False
# 11957    False
# 11958    False
# 11959    False
# Name: Target, Length: 11186, dtype: bool

# %% [markdown]
# Data visulaization

# %%
df.hist(figsize=(10,10))
plt.show()

# %%
# Plotting Countplot to show Attacks per Year
plt.figure(figsize=(15,5))
sns.countplot(x = df['Year'])
plt.title('Terrorist Activities per Year')
plt.xlabel('Attacking Years')
plt.ylabel('No. of Attacks per Years')
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(15,6))
plt.xticks(rotation=90)
plt.title("attack on dif way")
sns.countplot(x=df['Day'])
# Out:
# <Axes: title={'center': 'attack on dif way'}, xlabel='Day', ylabel='count'>

# %%
pd.crosstab(df.Year,df.Region).plot(kind='area')
# Out:
# <Axes: xlabel='Year'>
